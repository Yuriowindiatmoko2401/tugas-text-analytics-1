# %% [markdown]
# ## library 2 utama yang diperlukan

# %%
import re, unicodedata
import nltk
from nltk import word_tokenize
from nltk.corpus import stopwords
import pandas as pd

# nltk.download('stopwords')
# nltk.download('punkt')

# %%
stop_words = set(stopwords.words('indonesian')) # stop words indonesia , untuk membuang kata2 yg kurang bermakna
# stop_words.add("wib")

# %%
def rmNon_Ascii(text): # membuang character ascii atau emoticon 
    return unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')

def rmURLs(text): # membuang url
    return re.sub(r'(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:\'".,<>?«»“”‘’]))', '', text)

def rmPunc(text): # membuang tanda baca
    return re.sub(r'[^\w]|_',' ',text)

def rmDigit_string(text): # membuang digit didalam string 
    return re.sub("\S*\d\S*", "", text).strip()

def rmDigitnumbers(text): # membuang digit dan angka
    return re.sub(r"\b\d+\b", " ", text)

def rmHashtag(text): # membuang hashtag
    return re.sub(r"#(\w+)", ' ', text, flags=re.MULTILINE)

def rmMention(text): # membuang mention
    return re.sub(r"@(\w+)", ' ', text, flags=re.MULTILINE)

def rmXML(text): # membuang xml character
    return re.sub("&(?:#([0-9]+)|#x([0-9a-fA-F]+)|([0-9a-zA-Z]+));"," ",text)

def rmRT(text): # membuang retweet atau RT
    return re.sub("\s*RT\s*@[^:]*"," ",text)

def lowercase(text): # casefolding menjadi huruf kecil
    return text.lower()

def rmAdditionalWs(text): # membuang spasi2 tambahan
    return re.sub('[\s]+', ' ', text)

def removeStopword(text,stop_words=stop_words): # membuang kata2 yang terdapat pada stopwords id
    word_tokens = word_tokenize(text)
    filtered_sentence = [w for w in word_tokens if not w in stop_words]
    return ' '.join(filtered_sentence)

# %%
df = pd.read_csv('tweet-data.txt',delimiter="\n",header=None) # membaca data menjadi dataframe dengan delimiter newline

# %%
df = df.rename(columns={0: "tweets"}) # memberi nama column header tweets

# %%
pd.options.display.max_colwidth = 1000 # mengoptimalkan display dataframe pada value column nya

# %% [markdown]
# ### text preprocess
#
# ##### arah flow tahapan preprocess twit
# tweet >> membuang XML char >> rmNon_Ascii >> rmRT >> rmHashtag >> rmMention >> rmURLs >> rmPunc >> rmAdditionalWs >> lowercase >> removeStopword >> rmDigitnumbers

# %%
df["clean_tweets"] = df.tweets.apply(lambda x: 
    rmDigitnumbers(removeStopword(lowercase(rmAdditionalWs(rmPunc(rmURLs(rmMention(rmHashtag(rmRT(rmNon_Ascii(rmXML(x))))
                                                                   ))))))))

# %%
df # show df
# Out:
#                                                                                                                                              tweets  \
# 0                                                         Siang, bisa langsung ditanyakan ke Kebidanan FK UB. Terima kasih. https://t.co/5P0KDHlK9r
# 1                                          Jadwal Kegiatan Dies Natalis ke-54 UB. Catat tanggalnya dan semarakkan acaranya. https://t.co/YZpBV1YFJK
# 2                                                    Coming soon : Rangkaian Acara Dies Natalis ke-54 Universitas Brawijaya https://t.co/5xgu0Gj828
# 3      RT @UB_IO: Beasiswa AMINEF Untuk Pengajar Bahasa Inggris di UB. Deadline aplikasi tanggal 15 April 2017 https://t.co/Kg5Ked96bf @UB_Official
# 4                               RT @UB_IO: Beasiswa untuk Training dan Studi Lanjut ke Belgia. @UB_Official @UBTV_Brawijaya https://t.co/eEHYiNzbrf
# 5   RT @UB_IT: Periksa Soal: cek jawaban kamu.Untuk kembali ke soal,klik nomornya.Tombol SELESAI di klik jika semua soal sudah dijawab &amp; nilai…
# 6       RT @UB_IT: Tes kompetensi TI selama 90 menit/90 soal (30 Excel,30 P.Point,30 Word). Soal tiap orang berbeda krn bank soal lebih dari 3000.…
# 7      RT @UnileverIDN: Prosesi penutupan Bulan Kesehatan Gigi Nasional 2016 di FKG Univ Brawijaya #BKGN #Pepsodent @UB_Official @TanyaPepsodent @…
# 8                      Selamat siang. Untuk jadwal penerimaan mahasiswa S2 bisa dilihat di https://t.co/1Uuv3lGe1O atau di… https://t.co/CYvxFREg3M
# 9      RT @kempanrb: bersama Korpri meneguhkan netralitas dan meningkatkan profesionalisme Aparatur Sipil Negara. Selamat HUT KORPRI ke 45!! https…
# 10      RT @UB_IO: Sosialisasi Studi S2 dan Beasiswa dari Swedia. hari ini, 16.00-17.00 di Lt.8 Rektorat UB, Free entry, kuota terbatas 150 kursi.…
# 11     RT @UB_IO: Kesempatan terbaru untuk studi S2 dan S3 di luar negeri dengan beasiswa. Informasi lebih lengkap https://t.co/u0RkZJTtsV @UB_Off…
# 12       RT @UB_IO: Don't forget, British Winter Education Fair, Today 13.00 at Gedung Kebudayaan Mahasiswa UB https://t.co/dsel5k3Ii9 @UB_Official
# 13                                       RT @UB_IO: Program Pertukaran Pelajar dari AMINEF untuk D1, D3 dan S1 https://t.co/rwV7N7sAX6 @UB_Official
# 14                        RT @UB_IO: Fullbright Scholarship untuk S2 dan S3 telah dibuka, silahkan mengunjungi https://t.co/FbNchPlT9W @UB_Official
# 15     RT @UB_IO: British Winter Education Fair. Don't miss it. Scholarships info and many more @UB_Official @UBTV_Brawijaya https://t.co/iA0e6uHB…
# 16          RT @UB_IO: International Student Summit adalah agenda tahunan DIKTI untuk kompetisi mahasiswa asing dan lokal se-Indonesia @UB_Official
# 17     RT @UB_IO: Sosialisasi International Student Summit and Competition by UNAIR. Hari ini Kamis 13/10/16 pukul 12.00, di Lt8 Rektorat. Free. @…
# 18                                                                         RT @UB_IT: Pengumuman Jadwal Test Sertifikasi Kompetensi TI Gelombang 54
# 19                                                                                                                          https://t.co/vhHiWN0ENq
# 20     RT @UB_IO: Nuffic Neso dan DAAD menawarkan beasiswa pendidikan untuk S1 hingga S3, summer course, dan pelatihan https://t.co/u0RkZJTtsV @UB…
# 21                RT @UB_IO: Salah satu partner UB, Ritsumeikan University membuka Short-term Exchange Program https://t.co/fc4FcPASoN @UB_Official
# 22                   Rektor : selamat dan berbahagialah menjadi bagian dari 12.000 mahasiswa baru UB. Selamat belajar. #RajaBrawijaya2016 #Pusaka54
# 23                                                             Pelepasan balon oleh Rektor dan Dirjen dari Kemenristekdikti https://t.co/kBReodtkIk
# 24          Dengan dibunyikannya gong, secara resmi telah dimulainya pelaksanaan PKK-Maba 2016 #RajaBrawijaya2016 #Pusaka54 https://t.co/Xe7Hfj3TqO
# 25                                 Rektor Universitas Brawijaya beserta jajaran dan undangan memasuki lapangan upacara #RajaBrawijaya2016 #Pusaka54
# 26                                                                                                              Ayo Dukung! https://t.co/ZuCSWMojex
# 27                   #INFO 4. Pintu gerbang dibuka pada Selasa, 30 Agustus 2016, pukul 09.00 WIB-15.30 WIB dan 17.00 WIB-selesai #RajaBrawijaya2016
# 28                            #INFO 3. Pintu Gerbang keluar yang dibuka : Pintu Gerbang Pos Veteran dan Pintu Gerbang Pos BNI'46 #RajaBrawijaya2016
# 29                #INFO 2. Penutupan dilaksanakan pada hari : Selasa, 30 Agustus 2016, pukul 06.30-09.00 WIB dan 15.30-17.00 WIB #RajaBrawijaya2016
# 30          #INFO 1. Penutupan jalan masuk pada : Pintu Gerbang Pos Veteran, Pos BNI'46, Pos Jl, M. Haryono (Makam) dan Pos KPRI #RajaBrawijaya2016
# 31                                     #INFO Sehubungan dengan akan diselenggarakannya PKK-Maba #RajaBrawijaya2016 dengan ini diberitahukan bahwa :
#
#                                                                                                   clean_tweets
# 0                                                                  siang langsung kebidanan fk ub terima kasih
# 1                                       jadwal kegiatan dies natalis   ub catat tanggalnya semarakkan acaranya
# 2                                             coming soon rangkaian acara dies natalis   universitas brawijaya
# 3                               beasiswa aminef pengajar bahasa inggris ub deadline aplikasi tanggal   april
# 4                                                                               beasiswa training studi belgia
# 5                                                          periksa cek klik nomornya tombol selesai klik nilai
# 6                                tes kompetensi ti   menit     excel   p point   word orang berbeda krn bank
# 7                                               prosesi penutupan kesehatan gigi nasional   fkg univ brawijaya
# 8                                                                 selamat siang jadwal penerimaan mahasiswa s2
# 9   korpri meneguhkan netralitas meningkatkan profesionalisme aparatur sipil negara selamat hut korpri   https
# 10             sosialisasi studi s2 beasiswa swedia         lt   rektorat ub free entry kuota terbatas   kursi
# 11                                            kesempatan terbaru studi s2 s3 negeri beasiswa informasi lengkap
# 12                      don t forget british winter education fair today     at gedung kebudayaan mahasiswa ub
# 13                                                                  program pertukaran pelajar aminef d1 d3 s1
# 14                                                    fullbright scholarship s2 s3 dibuka silahkan mengunjungi
# 15                                 british winter education fair don t miss it scholarships info and many more
# 16                 international student summit agenda tahunan dikti kompetisi mahasiswa asing lokal indonesia
# 17         sosialisasi international student summit and competition by unair kamis           lt8 rektorat free
# 18                                                pengumuman jadwal test sertifikasi kompetensi ti gelombang
# 19
# 20                               nuffic neso daad menawarkan beasiswa pendidikan s1 s3 summer course pelatihan
# 21                                 salah partner ub ritsumeikan university membuka short term exchange program
# 22                                               rektor selamat berbahagialah     mahasiswa ub selamat belajar
# 23                                                              pelepasan balon rektor dirjen kemenristekdikti
# 24                                                             dibunyikannya gong resmi pelaksanaan pkk maba
# 25                             rektor universitas brawijaya beserta jajaran undangan memasuki lapangan upacara
# 26                                                                                                  ayo dukung
# 27                                     pintu gerbang dibuka selasa   agustus       wib     wib     wib selesai
# 28                                      pintu gerbang dibuka pintu gerbang pos veteran pintu gerbang pos bni
# 29                                           penutupan dilaksanakan selasa   agustus           wib         wib
# 30                   penutupan jalan masuk pintu gerbang pos veteran pos bni   pos jl m haryono makam pos kpri
# 31                                                        sehubungan diselenggarakannya pkk maba diberitahukan

# %%
# membuat daftar list of list untuk format corpus khusus dalam pemodelan gensim word2vec
ls_of = [df.clean_tweets[i].split() for i in range(len(df)) if df.clean_tweets[i].split() != []]

# %%
from gensim.models import Word2Vec # import word2vec gensim

# %%
model = Word2Vec(ls_of, min_count=1,size= 4,workers=3, window =3, sg = 1) # training vector kata dengan ukuran vektor 4 , 
# 1 untuk skip gram model jika 0 CBOW model, dengan window 3 kata pada sebuah kalimat , min_count 1 kata pada kalimat , 
# ls_of list of list yang akan dijadikan corpus

# %%
# summary dari vocabulary corpus
print(model)

words = list(model.wv.vocab)
print(words[0:5])
# Out:
# Word2Vec(vocab=192, size=4, alpha=0.025)
# ['siang', 'langsung', 'kebidanan', 'fk', 'ub']

# %%
# contoh mengakses vector untuk satu kata sebagai referensi
print(model.wv['ub'])
# Out:
# [ 0.11884184  0.12117017 -0.02563052 -0.01053343]

# %%
from sklearn.decomposition import PCA # mendapatkan fungsi PCA untuk mereduksi dimensi

# Plotting helpers
import matplotlib
import matplotlib.pyplot as plt

# %%
# fitting sebuah 2d PCA model ke dalam vector
X = model.wv[model.wv.vocab]
pca = PCA(n_components=2)
result = pca.fit_transform(X)

# %%
# membuat sebuah plot dari proyeksi corpus dalam 2 dimensi setelah direduksi dari 4 dimensi vector
fig, ax = plt.subplots()
ax.plot(result[:, 0], result[:, 1], 'o')
ax.set_title('Tweets')
plt.show()

# %%
# Memperjelas plotting hubungan kedekatan antar kata dari training word2vec
fig, ax = plt.subplots(figsize=(18, 13))
ax.plot(result[:, 0], result[:, 1], 'o')
ax.set_title('Tweets')
ax.set_yticklabels([]) #Hide ticks
ax.set_xticklabels([]) #Hide ticks

words = list(model.wv.vocab)
for i, word in enumerate(words):
	plt.annotate(word, xy=(result[i, 0], result[i, 1]))
plt.show()

# %%
#t-SNE
#Import the t-SNE 
from sklearn.manifold import TSNE

# %%
tsne = TSNE(n_components=2)

# %%
Y = tsne.fit_transform(X)

# %%
#Plot the t-SNE output
fig, ax = plt.subplots()
ax.plot(Y[:, 0], Y[:, 1], 'o')
ax.set_title('Tweets')
ax.set_yticklabels([]) #Hide ticks
ax.set_xticklabels([]) #Hide ticks
plt.show()

# %%
# plotting tsne dengan label kata.
fig, ax = plt.subplots(figsize=(18, 13))
ax.plot(Y[:, 0], Y[:, 1], 'o')
ax.set_title('Tweets')
ax.set_yticklabels([]) #Hide ticks
ax.set_xticklabels([]) #Hide ticks

words = list(model.wv.vocab)
for i, word in enumerate(words):
	plt.annotate(word, xy=(Y[i, 0], Y[i, 1]))
plt.show()

# %%
# !ls
# Out:
# 19917020_Yurio_txt1.ipynb
# LICENSE
# README.md
# Scraping_Preprocessing_Data_Visualization.ipynb
# Scraping_Preprocessing_Data_Visualization.py
# pca_viz.png
# preprocessing.ipynb
# preprocessing.py
# preprocessing_dtws.ipynb
# preprocessing_dtws.py
# tweet-data.txt

# %% [markdown]
# ## kesimpulan dimensi reduksi dengan pca lebih dapat menjawab keterkaitan antar kata seperti
#
# <img src="pca_viz.png" width="80%">
